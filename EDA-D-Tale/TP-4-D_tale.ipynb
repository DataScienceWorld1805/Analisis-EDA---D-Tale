# %%
# Instalar D-Tale
# !pip install dtale seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importar librerías
import dtale
import seaborn as sns
import pandas as pd
import warnings
# Out:
# c:\Users\martin\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
warnings.filterwarnings("ignore")

# %%
# Cargar el dataset Homicidios
df = pd.read_csv("database.csv")

# %%
# Iniciar D-Tale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-CC9Q84T:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
